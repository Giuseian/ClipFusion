# %% [markdown]
# ### **1. Import libraries**

# %%
# all necessary imports
import numpy as np 
import pandas as pd 
import re
from collections import Counter
import os
import json
import string
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
import transformers
import torch
from torch.utils.data import Dataset
from datasets import Dataset
from dataclasses import dataclass
from transformers.tokenization_utils_base import PreTrainedTokenizerBase, PaddingStrategy
from typing import Optional, Union
import torch as T
import numpy as np
from transformers import AutoModelForMultipleChoice, TrainingArguments, Trainer
import torch.nn as nn
from transformers import AutoTokenizer
from torch.utils.data import DataLoader
from argparse import Namespace
from transformers import BertModel
from transformers import AdamW
from PIL import Image
import requests
import cv2 
from transformers import CLIPProcessor, CLIPModel
import shutil 
import math
import torch.optim as optim
from PIL import Image
import cv2 
from transformers import CLIPProcessor, CLIPModel
import pickle 
from sklearn.model_selection import train_test_split

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# !pip install datasets --upgrade
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# !pip install ipywidgets --upgrade
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.13)
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json

# %% [markdown]
# ### **2.MSRVTT-RETRIEVAL PREPROCESSING**

# %%
MSRVTT_MC = "/kaggle/input/msrvtt-retrieval/mc_test.jsonl"
MSRVTT_TRAIN = "/kaggle/input/msrvtt-retrieval/train.jsonl"
MSRVTT_VAL = "/kaggle/input/msrvtt-retrieval/val.jsonl"
MSRVTT_TEST = "/kaggle/input/msrvtt-retrieval/test.jsonl"
# MSRVTT_TRAIN_VAL_VIDEO = "/kaggle/input/msrvttqa/archive/TrainValVideo"
MSRVTT_TEST_VIDEO = "/kaggle/input/msrvtt-test-video/MSRVTT/videos/all"
MSRVTT_OUTPUT = "/kaggle/working/msrvtt"
MSRVTT_VIDEO_PREPROCESSED = "/kaggle/working/msrvtt_video"

# %%
try:
    os.makedirs(MSRVTT_OUTPUT)
    print(f"Directory '{MSRVTT_OUTPUT}' created successfully.")
except FileExistsError:
    print(f"Directory '{MSRVTT_OUTPUT}' already exists.")
# Out:
# Directory '/kaggle/working/msrvtt' created successfully.

# %%
def convert_jsonl_to_json(input_jsonl_file, output_json_folder):
    # Ensure the output folder exists
    os.makedirs(output_json_folder, exist_ok=True)
    
    # Determine the output JSON filename
    base_name = os.path.splitext(os.path.basename(input_jsonl_file))[0]
    output_json_file = os.path.join(output_json_folder, base_name + '.json')
    
    # Read the JSONL file and aggregate the data
    data = []
    with open(input_jsonl_file, 'r') as jsonl_file:
        for line_number, line in enumerate(jsonl_file, start=1):
            line = line.strip()
            if not line:  # Skip empty lines
                continue
            try:
                data.append(json.loads(line))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {line_number}: {e}")
                continue
    
    # Write to the JSON file
    with open(output_json_file, 'w') as json_file:
        json.dump(data, json_file, indent=4)
    
    print(f"Converted {input_jsonl_file} to {output_json_file}")
    return output_json_file

# %%
MSRVTT_MC_JSON = convert_jsonl_to_json(MSRVTT_MC, MSRVTT_OUTPUT)
MSRVTT_TRAIN_JSON = convert_jsonl_to_json(MSRVTT_TRAIN, MSRVTT_OUTPUT)
MSRVTT_VAL_JSON = convert_jsonl_to_json(MSRVTT_VAL, MSRVTT_OUTPUT)
MSRVTT_TEST_JSON = convert_jsonl_to_json(MSRVTT_TEST, MSRVTT_OUTPUT)
# Out:
# Converted /kaggle/input/msrvtt-retrieval/mc_test.jsonl to /kaggle/working/msrvtt/mc_test.json
# Converted /kaggle/input/msrvtt-retrieval/train.jsonl to /kaggle/working/msrvtt/train.json
# Converted /kaggle/input/msrvtt-retrieval/val.jsonl to /kaggle/working/msrvtt/val.json
# Converted /kaggle/input/msrvtt-retrieval/test.jsonl to /kaggle/working/msrvtt/test.json

# %%
# Loading JSON Files 
with open(MSRVTT_MC_JSON, 'r') as msrvtt_mc, open(MSRVTT_TRAIN_JSON, 'r') as msrvtt_train, open(MSRVTT_VAL_JSON, 'r') as msrvtt_val, open(MSRVTT_TEST_JSON, 'r') as msrvtt_test :
    msrvtt_mc = json.load(msrvtt_mc)
    msrvtt_train = json.load(msrvtt_train)
    msrvtt_val = json.load(msrvtt_val)
    msrvtt_test = json.load(msrvtt_test)
#print(msrvtt)

# Converting JSON Files to DataFrame 
msrvtt_mc = pd.DataFrame(msrvtt_mc)
msrvtt_train = pd.DataFrame(msrvtt_train)
msrvtt_val = pd.DataFrame(msrvtt_val)
msrvtt_test = pd.DataFrame(msrvtt_test)

msrvtt_mc
# Out:
#          qid  clip_name      title answer  \
# 0        mc0  video9770  msr143897      0
# 1        mc1  video9771  msr169115      2
# 2        mc2  video7020  msr160593      2
# 3        mc3  video9773  msr145898      3
# 4        mc4  video7026  msr162877      2
# ...      ...        ...        ...    ...
# 2985  mc2985  video7937  msr195060      2
# 2986  mc2986  video7930  msr183709      4
# 2987  mc2987  video7931  msr174474      2
# 2988  mc2988  video7932  msr178667      1
# 2989  mc2989  video7933  msr177470      2
#
#                                                 options
# 0     [the boy is trying to fix the problem, a movie...
# 1     [a man dismisses a group of soldiers and a sce...
# 2     [a wining team celebrates their victory at the...
# 3     [a man yells at a faucet then punches it, peop...
# 4     [basically humans have helping intensity, a ro...
# ...                                                 ...
# 2985  [a male singer performs before a live audience...
# 2986  [a journalist talking to a guest, a woman head...
# 2987  [animated characters from the beauty and the b...
# 2988  [a man is laying in bed next to a woman and sh...
# 2989  [guy recording video of his baby trying to get...
#
# [2990 rows x 5 columns]

# %%
# Converting msrvtt_mc to OUR STANDARD FORMAT 

msrvtt = msrvtt_mc.copy() 
# Split the 'options' column into 5 separate columns 'a1', 'a2', 'a3', 'a4', 'a5'
msrvtt[['a1', 'a2', 'a3', 'a4', 'a5']] = pd.DataFrame(msrvtt['options'].tolist(), index=msrvtt.index)

# Rename the 'qid' column to 'id' (as specified in the new order)
msrvtt = msrvtt.rename(columns={'qid': 'id'})

# Reorder the columns as requested
msrvtt = msrvtt[['title','id', 'clip_name', 'a1', 'a2', 'a3', 'a4', 'a5', 'answer']]

# Print the reordered DataFrame
msrvtt
# Out:
#           title      id  clip_name  \
# 0     msr143897     mc0  video9770
# 1     msr169115     mc1  video9771
# 2     msr160593     mc2  video7020
# 3     msr145898     mc3  video9773
# 4     msr162877     mc4  video7026
# ...         ...     ...        ...
# 2985  msr195060  mc2985  video7937
# 2986  msr183709  mc2986  video7930
# 2987  msr174474  mc2987  video7931
# 2988  msr178667  mc2988  video7932
# 2989  msr177470  mc2989  video7933
#
#                                                      a1  \
# 0                  the boy is trying to fix the problem
# 1     a man dismisses a group of soldiers and a scen...
# 2     a wining team celebrates their victory at the ...
# 3               a man yells at a faucet then punches it
# 4               basically humans have helping intensity
# ...                                                 ...
# 2985      a male singer performs before a live audience
# 2986                    a journalist talking to a guest
# 2987  animated characters from the beauty and the be...
# 2988  a man is laying in bed next to a woman and she...
# 2989  guy recording video of his baby trying to get ...
#
#                                                      a2  \
# 0     a movie trailer shows various scenes from a movie
# 1                            a woman pushing a stroller
# 2                             halo warriors music video
# 3                            people on a video laughing
# 4                         a rock band preforming a song
# ...                                                 ...
# 2985         a male narrating a video game in the image
# 2986                            a woman headbutts a man
# 2987  the man talks about how 7 million people are l...
# 2988  a promo for a tv show or movie with spoken wor...
# 2989                   a person is explaining something
#
#                                                      a3  \
# 0     asian man discusses technology in the younger ...
# 1                            a young girl is in the gym
# 2         a woman wraps a baby doll in some fake leaves
# 3               a group of people on stage on the voice
# 4     the announcer talks about the interior feature...
# ...                                                 ...
# 2985  a curious gerbil peeks out of a white tube loo...
# 2986  two girls going in a taxi while both speaking ...
# 2987                   the person talks about the woman
# 2988  a young man in an ill fitting suit gives a pre...
# 2989                        its the beginning of a show
#
#                                                      a4  \
# 0     two men on wave runner in ocean rescuing a surfer
# 1     a woman is putting items into a miniature toy ...
# 2                             people are playingg match
# 3             an advertisement for a driving video game
# 4     many women are walking on a runway in brown an...
# ...                                                 ...
# 2985                  a group of women preform on stage
# 2986              a cartoon character is carrying a gun
# 2987         a boy is describing the back of a computer
# 2988  there is a brown hair woman talking from the k...
# 2989  a man and woman are speaking about how hardcor...
#
#                                                      a5 answer
# 0                                    a group is dancing      0
# 1                       a game show host hosting a game      2
# 2                     a person solving the rubik s cube      2
# 3                      a person is playing a video game      3
# 4                           a man carries a green block      2
# ...                                                 ...    ...
# 2985             several people taste testing something      2
# 2986  a young woman in a red and white striped shirt...      4
# 2987                             someone is making food      2
# 2988  a person zooms into the welcome board of a pla...      1
# 2989                                   a man is talking      2
#
# [2990 rows x 9 columns]

# %%
# Concatenating both val and test 
msrvtt_total = pd.concat([msrvtt_val,msrvtt_test])

# Cross Join between msrvtt and msrvtt_total so to associate each caption to its answers 
final_msrvtt = pd.merge(msrvtt, msrvtt_total[['clip_name', 'caption']], on='clip_name', how='left')
print(final_msrvtt.isnull().sum())
final_msrvtt
# Out:
# title          0
# id             0
# clip_name      0
# a1             0
# a2             0
# a3             0
# a4             0
# a5             0
# answer         0
# caption      990
# dtype: int64
#           title      id  clip_name  \
# 0     msr143897     mc0  video9770
# 1     msr169115     mc1  video9771
# 2     msr160593     mc2  video7020
# 3     msr145898     mc3  video9773
# 4     msr162877     mc4  video7026
# ...         ...     ...        ...
# 2985  msr195060  mc2985  video7937
# 2986  msr183709  mc2986  video7930
# 2987  msr174474  mc2987  video7931
# 2988  msr178667  mc2988  video7932
# 2989  msr177470  mc2989  video7933
#
#                                                      a1  \
# 0                  the boy is trying to fix the problem
# 1     a man dismisses a group of soldiers and a scen...
# 2     a wining team celebrates their victory at the ...
# 3               a man yells at a faucet then punches it
# 4               basically humans have helping intensity
# ...                                                 ...
# 2985      a male singer performs before a live audience
# 2986                    a journalist talking to a guest
# 2987  animated characters from the beauty and the be...
# 2988  a man is laying in bed next to a woman and she...
# 2989  guy recording video of his baby trying to get ...
#
#                                                      a2  \
# 0     a movie trailer shows various scenes from a movie
# 1                            a woman pushing a stroller
# 2                             halo warriors music video
# 3                            people on a video laughing
# 4                         a rock band preforming a song
# ...                                                 ...
# 2985         a male narrating a video game in the image
# 2986                            a woman headbutts a man
# 2987  the man talks about how 7 million people are l...
# 2988  a promo for a tv show or movie with spoken wor...
# 2989                   a person is explaining something
#
#                                                      a3  \
# 0     asian man discusses technology in the younger ...
# 1                            a young girl is in the gym
# 2         a woman wraps a baby doll in some fake leaves
# 3               a group of people on stage on the voice
# 4     the announcer talks about the interior feature...
# ...                                                 ...
# 2985  a curious gerbil peeks out of a white tube loo...
# 2986  two girls going in a taxi while both speaking ...
# 2987                   the person talks about the woman
# 2988  a young man in an ill fitting suit gives a pre...
# 2989                        its the beginning of a show
#
#                                                      a4  \
# 0     two men on wave runner in ocean rescuing a surfer
# 1     a woman is putting items into a miniature toy ...
# 2                             people are playingg match
# 3             an advertisement for a driving video game
# 4     many women are walking on a runway in brown an...
# ...                                                 ...
# 2985                  a group of women preform on stage
# 2986              a cartoon character is carrying a gun
# 2987         a boy is describing the back of a computer
# 2988  there is a brown hair woman talking from the k...
# 2989  a man and woman are speaking about how hardcor...
#
#                                                      a5 answer  \
# 0                                    a group is dancing      0
# 1                       a game show host hosting a game      2
# 2                     a person solving the rubik s cube      2
# 3                      a person is playing a video game      3
# 4                           a man carries a green block      2
# ...                                                 ...    ...
# 2985             several people taste testing something      2
# 2986  a young woman in a red and white striped shirt...      4
# 2987                             someone is making food      2
# 2988  a person zooms into the welcome board of a pla...      1
# 2989                                   a man is talking      2
#
#                                          caption
# 0     a person is connecting something to system
# 1                  a little girl does gymnastics
# 2     a woman creating a fondant baby and flower
# 3                 a boy plays grand theft auto 5
# 4          a man is giving a review on a vehicle
# ...                                          ...
# 2985                                         NaN
# 2986                                         NaN
# 2987                                         NaN
# 2988                                         NaN
# 2989                                         NaN
#
# [2990 rows x 10 columns]

# %%
# Final Dataframe, completed with Caption -> dropped Videos with Nan Captions (990 videos )
final_msrvtt = final_msrvtt.rename(columns={'caption': 'question'})
final_msrvtt = final_msrvtt.dropna(subset=["question"])

# Reorder the columns as requested
final_msrvtt = final_msrvtt[['title', 'id', 'clip_name', 'question', 'a1', 'a2', 'a3', 'a4', 'a5', 'answer']]

print(final_msrvtt.isnull().sum())
final_msrvtt
# Out:
# title        0
# id           0
# clip_name    0
# question     0
# a1           0
# a2           0
# a3           0
# a4           0
# a5           0
# answer       0
# dtype: int64
#           title      id  clip_name  \
# 0     msr143897     mc0  video9770
# 1     msr169115     mc1  video9771
# 2     msr160593     mc2  video7020
# 3     msr145898     mc3  video9773
# 4     msr162877     mc4  video7026
# ...         ...     ...        ...
# 2972  msr141250  mc2972  video9737
# 2977  msr152848  mc2977  video8002
# 2981  msr159368  mc2981  video8006
# 2982  msr158401  mc2982  video7934
# 2984  msr166104  mc2984  video7936
#
#                                                question  \
# 0            a person is connecting something to system
# 1                         a little girl does gymnastics
# 2            a woman creating a fondant baby and flower
# 3                        a boy plays grand theft auto 5
# 4                 a man is giving a review on a vehicle
# ...                                                 ...
# 2972             a news clip from rt of a terror attack
# 2977                  a man is folding a piece of paper
# 2981  a person flying in a helicopter and is going t...
# 2982                  some women are dancing on a stage
# 2984  soccer players are hugging and celebrating a goal
#
#                                                      a1  \
# 0                  the boy is trying to fix the problem
# 1     a man dismisses a group of soldiers and a scen...
# 2     a wining team celebrates their victory at the ...
# 3               a man yells at a faucet then punches it
# 4               basically humans have helping intensity
# ...                                                 ...
# 2972  a bloomberg analyst talking about growth in ma...
# 2977                        a person is folding origami
# 2981  a woman talking about the movie brooklyn nine ...
# 2982           a video game about car race and shooting
# 2984  this is a old footage of a wwf wrestling match...
#
#                                                      a2  \
# 0     a movie trailer shows various scenes from a movie
# 1                            a woman pushing a stroller
# 2                             halo warriors music video
# 3                            people on a video laughing
# 4                         a rock band preforming a song
# ...                                                 ...
# 2972  three girls at a public place and young man sh...
# 2977  a man explains about a disease called kuru dis...
# 2981              a person is preparing a food on a pan
# 2982  red headed woman is travelling in europe by ai...
# 2984                              person preparing food
#
#                                                      a3  \
# 0     asian man discusses technology in the younger ...
# 1                            a young girl is in the gym
# 2         a woman wraps a baby doll in some fake leaves
# 3               a group of people on stage on the voice
# 4     the announcer talks about the interior feature...
# ...                                                 ...
# 2972  the girl is inside the gaming side and the jol...
# 2977  shrimp is being shown and it seems that they a...
# 2981                        a reel of sports highlights
# 2982                  a girl group performance on stage
# 2984                          a soccer game in progress
#
#                                                      a4  \
# 0     two men on wave runner in ocean rescuing a surfer
# 1     a woman is putting items into a miniature toy ...
# 2                             people are playingg match
# 3             an advertisement for a driving video game
# 4     many women are walking on a runway in brown an...
# ...                                                 ...
# 2972  a news video showing the aftermath of a terror...
# 2977                      slide show of couples in love
# 2981            a video game plane is flying over water
# 2982  chefs and waiters move about in a very large k...
# 2984                      old clip from a baseball game
#
#                                                      a5 answer
# 0                                    a group is dancing      0
# 1                       a game show host hosting a game      2
# 2                     a person solving the rubik s cube      2
# 3                      a person is playing a video game      3
# 4                           a man carries a green block      2
# ...                                                 ...    ...
# 2972  an education analyst speaks about the data sci...      3
# 2977  nba star tracy mcgrady is being interviewed in...      0
# 2981                          a person is folding paper      3
# 2982                           game scene is shown here      2
# 2984               a man in his garage showing his cars      2
#
# [2000 rows x 10 columns]

# %%
# Checking for empty strings 
print(final_msrvtt.equals(""))
# Out:
# False

# %%
# Converting to Lowercase
text_columns = ['title','id', 'clip_name','question', 'a1', 'a2', 'a3', 'a4', 'a5']

final_msrvtt[text_columns] = final_msrvtt[text_columns].apply(lambda x: x.str.lower())

final_msrvtt
# stop_words = set(stopwords.words('english'))
#cleaned_msrvtt = " ".join([word for word in text.split() if word not in stop_words])
# Out:
#           title      id  clip_name  \
# 0     msr143897     mc0  video9770
# 1     msr169115     mc1  video9771
# 2     msr160593     mc2  video7020
# 3     msr145898     mc3  video9773
# 4     msr162877     mc4  video7026
# ...         ...     ...        ...
# 2972  msr141250  mc2972  video9737
# 2977  msr152848  mc2977  video8002
# 2981  msr159368  mc2981  video8006
# 2982  msr158401  mc2982  video7934
# 2984  msr166104  mc2984  video7936
#
#                                                question  \
# 0            a person is connecting something to system
# 1                         a little girl does gymnastics
# 2            a woman creating a fondant baby and flower
# 3                        a boy plays grand theft auto 5
# 4                 a man is giving a review on a vehicle
# ...                                                 ...
# 2972             a news clip from rt of a terror attack
# 2977                  a man is folding a piece of paper
# 2981  a person flying in a helicopter and is going t...
# 2982                  some women are dancing on a stage
# 2984  soccer players are hugging and celebrating a goal
#
#                                                      a1  \
# 0                  the boy is trying to fix the problem
# 1     a man dismisses a group of soldiers and a scen...
# 2     a wining team celebrates their victory at the ...
# 3               a man yells at a faucet then punches it
# 4               basically humans have helping intensity
# ...                                                 ...
# 2972  a bloomberg analyst talking about growth in ma...
# 2977                        a person is folding origami
# 2981  a woman talking about the movie brooklyn nine ...
# 2982           a video game about car race and shooting
# 2984  this is a old footage of a wwf wrestling match...
#
#                                                      a2  \
# 0     a movie trailer shows various scenes from a movie
# 1                            a woman pushing a stroller
# 2                             halo warriors music video
# 3                            people on a video laughing
# 4                         a rock band preforming a song
# ...                                                 ...
# 2972  three girls at a public place and young man sh...
# 2977  a man explains about a disease called kuru dis...
# 2981              a person is preparing a food on a pan
# 2982  red headed woman is travelling in europe by ai...
# 2984                              person preparing food
#
#                                                      a3  \
# 0     asian man discusses technology in the younger ...
# 1                            a young girl is in the gym
# 2         a woman wraps a baby doll in some fake leaves
# 3               a group of people on stage on the voice
# 4     the announcer talks about the interior feature...
# ...                                                 ...
# 2972  the girl is inside the gaming side and the jol...
# 2977  shrimp is being shown and it seems that they a...
# 2981                        a reel of sports highlights
# 2982                  a girl group performance on stage
# 2984                          a soccer game in progress
#
#                                                      a4  \
# 0     two men on wave runner in ocean rescuing a surfer
# 1     a woman is putting items into a miniature toy ...
# 2                             people are playingg match
# 3             an advertisement for a driving video game
# 4     many women are walking on a runway in brown an...
# ...                                                 ...
# 2972  a news video showing the aftermath of a terror...
# 2977                      slide show of couples in love
# 2981            a video game plane is flying over water
# 2982  chefs and waiters move about in a very large k...
# 2984                      old clip from a baseball game
#
#                                                      a5 answer
# 0                                    a group is dancing      0
# 1                       a game show host hosting a game      2
# 2                     a person solving the rubik s cube      2
# 3                      a person is playing a video game      3
# 4                           a man carries a green block      2
# ...                                                 ...    ...
# 2972  an education analyst speaks about the data sci...      3
# 2977  nba star tracy mcgrady is being interviewed in...      0
# 2981                          a person is folding paper      3
# 2982                           game scene is shown here      2
# 2984               a man in his garage showing his cars      2
#
# [2000 rows x 10 columns]

# %%
# Removing White Spaces 
final_msrvtt[text_columns] = final_msrvtt[text_columns].apply(lambda x: x.str.strip())

# Removing Punctuations 
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

final_msrvtt[text_columns] = final_msrvtt[text_columns].map(remove_punctuation)
final_msrvtt.head()
# Out:
#        title   id  clip_name                                    question  \
# 0  msr143897  mc0  video9770  a person is connecting something to system
# 1  msr169115  mc1  video9771               a little girl does gymnastics
# 2  msr160593  mc2  video7020  a woman creating a fondant baby and flower
# 3  msr145898  mc3  video9773              a boy plays grand theft auto 5
# 4  msr162877  mc4  video7026       a man is giving a review on a vehicle
#
#                                                   a1  \
# 0               the boy is trying to fix the problem
# 1  a man dismisses a group of soldiers and a scen...
# 2  a wining team celebrates their victory at the ...
# 3            a man yells at a faucet then punches it
# 4            basically humans have helping intensity
#
#                                                   a2  \
# 0  a movie trailer shows various scenes from a movie
# 1                         a woman pushing a stroller
# 2                          halo warriors music video
# 3                         people on a video laughing
# 4                      a rock band preforming a song
#
#                                                   a3  \
# 0  asian man discusses technology in the younger ...
# 1                         a young girl is in the gym
# 2      a woman wraps a baby doll in some fake leaves
# 3            a group of people on stage on the voice
# 4  the announcer talks about the interior feature...
#
#                                                   a4  \
# 0  two men on wave runner in ocean rescuing a surfer
# 1  a woman is putting items into a miniature toy ...
# 2                          people are playingg match
# 3          an advertisement for a driving video game
# 4  many women are walking on a runway in brown an...
#
#                                   a5 answer
# 0                 a group is dancing      0
# 1    a game show host hosting a game      2
# 2  a person solving the rubik s cube      2
# 3   a person is playing a video game      3
# 4        a man carries a green block      2

# %%
# Text Cleaning 

# Check if any cell in the DataFrame contains a special character
final_msrvtt.apply(lambda x: x.str.contains('[^a-zA-Z0-9_\- ]', na=False))

# Extract rows with special characters 
final_msrvtt[final_msrvtt.apply(lambda x: x.str.contains('[^a-zA-Z0-9_\- ]', na=False)).any(axis=1)]

# Remove special characters from all columns
final_msrvtt = final_msrvtt.apply(lambda x: x.str.replace('[^a-zA-Z0-9_\- ]', '', regex=True))

# To check if special characters were removed, then try to extract again rows that contain special characters -> if None is found, then the special character has been correctly replaced 
# final_msrvtt[final_msrvtt.apply(lambda x: x.str.contains('[^a-zA-Z0-9_\- ]', na=False)).any(axis=1)]

# %%
# Removing Stopwords 
stop = set(stopwords.words('english'))
def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop])
final_msrvtt[['title','id', 'clip_name','question', 'a1', 'a2', 'a3', 'a4', 'a5']] = final_msrvtt[['title','id', 'clip_name','question', 'a1', 'a2', 'a3', 'a4', 'a5']].map(remove_stopwords)

# %%
# Resetting the index 
last_msrvtt = final_msrvtt.copy() 
last_msrvtt.reset_index(drop=True, inplace=True)
last_msrvtt
# Out:
#           title      id  clip_name  \
# 0     msr143897     mc0  video9770
# 1     msr169115     mc1  video9771
# 2     msr160593     mc2  video7020
# 3     msr145898     mc3  video9773
# 4     msr162877     mc4  video7026
# ...         ...     ...        ...
# 1995  msr141250  mc2972  video9737
# 1996  msr152848  mc2977  video8002
# 1997  msr159368  mc2981  video8006
# 1998  msr158401  mc2982  video7934
# 1999  msr166104  mc2984  video7936
#
#                                          question  \
# 0              person connecting something system
# 1                          little girl gymnastics
# 2              woman creating fondant baby flower
# 3                    boy plays grand theft auto 5
# 4                       man giving review vehicle
# ...                                           ...
# 1995                   news clip rt terror attack
# 1996                      man folding piece paper
# 1997  person flying helicopter going shoot people
# 1998                          women dancing stage
# 1999      soccer players hugging celebrating goal
#
#                                                      a1  \
# 0                                boy trying fix problem
# 1     man dismisses group soldiers scene soldiers wa...
# 2               wining team celebrates victory end game
# 3                              man yells faucet punches
# 4                    basically humans helping intensity
# ...                                                 ...
# 1995      bloomberg analyst talking growth major cities
# 1996                             person folding origami
# 1997             woman talking movie brooklyn nine nine
# 1998                       video game car race shooting
# 1999         old footage wwf wrestling match hulk hogan
#
#                                                      a2  \
# 0              movie trailer shows various scenes movie
# 1                                woman pushing stroller
# 2                             halo warriors music video
# 3                                 people video laughing
# 4                             rock band preforming song
# ...                                                 ...
# 1995  three girls public place young man shouts medi...
# 1996           man explains disease called kuru disease
# 1997                          person preparing food pan
# 1998        red headed woman travelling europe airplane
# 1999                              person preparing food
#
#                                                      a3  \
# 0     asian man discusses technology younger generat...
# 1                                        young girl gym
# 2                     woman wraps baby doll fake leaves
# 3                              group people stage voice
# 4                 announcer talks interior features car
# ...                                                 ...
# 1995                 girl inside gaming side jolly mood
# 1996                          shrimp shown seems cooked
# 1997                             reel sports highlights
# 1998                       girl group performance stage
# 1999                               soccer game progress
#
#                                                      a4  \
# 0             two men wave runner ocean rescuing surfer
# 1                woman putting items miniature toy oven
# 2                                 people playingg match
# 3                      advertisement driving video game
# 4           many women walking runway brown red dresses
# ...                                                 ...
# 1995  news video showing aftermath terrorist attack ...
# 1996                            slide show couples love
# 1997                      video game plane flying water
# 1998                   chefs waiters move large kitchen
# 1999                             old clip baseball game
#
#                                                      a5 answer
# 0                                         group dancing      0
# 1                           game show host hosting game      2
# 2                             person solving rubik cube      2
# 3                             person playing video game      3
# 4                               man carries green block      2
# ...                                                 ...    ...
# 1995              education analyst speaks data science      3
# 1996  nba star tracy mcgrady interviewed beyond glor...      0
# 1997                               person folding paper      3
# 1998                                   game scene shown      2
# 1999                            man garage showing cars      2
#
# [2000 rows x 10 columns]

# %%
# Dictionary to store frequency of words 
combined_text = last_msrvtt[['question', 'a1', 'a2', 'a3', 'a4', 'a5']].apply(lambda x: ' '.join(x), axis=1)
word_counts = Counter(' '.join(combined_text).split())
word_count_dict = dict(word_counts)
#word_count_dict 

# Sort the dictionary by the word counts in descending order and convert back to a dictionary
sorted_word_count_dict = dict(sorted(word_counts.items(), key=lambda x: x[1], reverse=True))
#sorted_word_count_dict

# %%
tokenized_text = last_msrvtt.copy() 
def tokenize_text(text):
    if isinstance(text, str):  # Ensure the input is a string
        return word_tokenize(text)
    return []  # Return empty list for non-string input


tokenized_text[text_columns] = tokenized_text[text_columns].map(tokenize_text)

tokenized_text
# Out:
#             title        id    clip_name  \
# 0     [msr143897]     [mc0]  [video9770]
# 1     [msr169115]     [mc1]  [video9771]
# 2     [msr160593]     [mc2]  [video7020]
# 3     [msr145898]     [mc3]  [video9773]
# 4     [msr162877]     [mc4]  [video7026]
# ...           ...       ...          ...
# 1995  [msr141250]  [mc2972]  [video9737]
# 1996  [msr152848]  [mc2977]  [video8002]
# 1997  [msr159368]  [mc2981]  [video8006]
# 1998  [msr158401]  [mc2982]  [video7934]
# 1999  [msr166104]  [mc2984]  [video7936]
#
#                                                question  \
# 0               [person, connecting, something, system]
# 1                            [little, girl, gymnastics]
# 2              [woman, creating, fondant, baby, flower]
# 3                   [boy, plays, grand, theft, auto, 5]
# 4                        [man, giving, review, vehicle]
# ...                                                 ...
# 1995                   [news, clip, rt, terror, attack]
# 1996                       [man, folding, piece, paper]
# 1997  [person, flying, helicopter, going, shoot, peo...
# 1998                            [women, dancing, stage]
# 1999      [soccer, players, hugging, celebrating, goal]
#
#                                                      a1  \
# 0                           [boy, trying, fix, problem]
# 1     [man, dismisses, group, soldiers, scene, soldi...
# 2        [wining, team, celebrates, victory, end, game]
# 3                         [man, yells, faucet, punches]
# 4               [basically, humans, helping, intensity]
# ...                                                 ...
# 1995  [bloomberg, analyst, talking, growth, major, c...
# 1996                         [person, folding, origami]
# 1997      [woman, talking, movie, brooklyn, nine, nine]
# 1998                 [video, game, car, race, shooting]
# 1999  [old, footage, wwf, wrestling, match, hulk, ho...
#
#                                                      a2  \
# 0       [movie, trailer, shows, various, scenes, movie]
# 1                            [woman, pushing, stroller]
# 2                        [halo, warriors, music, video]
# 3                             [people, video, laughing]
# 4                        [rock, band, preforming, song]
# ...                                                 ...
# 1995  [three, girls, public, place, young, man, shou...
# 1996    [man, explains, disease, called, kuru, disease]
# 1997                     [person, preparing, food, pan]
# 1998  [red, headed, woman, travelling, europe, airpl...
# 1999                          [person, preparing, food]
#
#                                                      a3  \
# 0     [asian, man, discusses, technology, younger, g...
# 1                                    [young, girl, gym]
# 2              [woman, wraps, baby, doll, fake, leaves]
# 3                         [group, people, stage, voice]
# 4           [announcer, talks, interior, features, car]
# ...                                                 ...
# 1995          [girl, inside, gaming, side, jolly, mood]
# 1996                     [shrimp, shown, seems, cooked]
# 1997                         [reel, sports, highlights]
# 1998                  [girl, group, performance, stage]
# 1999                           [soccer, game, progress]
#
#                                                      a4  \
# 0     [two, men, wave, runner, ocean, rescuing, surfer]
# 1         [woman, putting, items, miniature, toy, oven]
# 2                             [people, playingg, match]
# 3                 [advertisement, driving, video, game]
# 4     [many, women, walking, runway, brown, red, dre...
# ...                                                 ...
# 1995  [news, video, showing, aftermath, terrorist, a...
# 1996                       [slide, show, couples, love]
# 1997                [video, game, plane, flying, water]
# 1998             [chefs, waiters, move, large, kitchen]
# 1999                        [old, clip, baseball, game]
#
#                                                      a5 answer
# 0                                      [group, dancing]      0
# 1                     [game, show, host, hosting, game]      2
# 2                        [person, solving, rubik, cube]      2
# 3                        [person, playing, video, game]      3
# 4                          [man, carries, green, block]      2
# ...                                                 ...    ...
# 1995        [education, analyst, speaks, data, science]      3
# 1996  [nba, star, tracy, mcgrady, interviewed, beyon...      0
# 1997                           [person, folding, paper]      3
# 1998                               [game, scene, shown]      2
# 1999                       [man, garage, showing, cars]      2
#
# [2000 rows x 10 columns]

# %%
last_msrvtt.iloc[1999]
# Out:
# title                                         msr166104
# id                                               mc2984
# clip_name                                     video7936
# question        soccer players hugging celebrating goal
# a1           old footage wwf wrestling match hulk hogan
# a2                                person preparing food
# a3                                 soccer game progress
# a4                               old clip baseball game
# a5                              man garage showing cars
# answer                                                2
# Name: 1999, dtype: object

# %% [markdown]
# ### **3. CLIP Model & Frame Embedding**

# %%
# Load CLIP model and processor from Hugging Face
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")
# Out:
# config.json:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def get_single_image_embedding(my_image):
    image = processor(
    		text = None,
    		images = my_image,
    		return_tensors="pt"
    		)["pixel_values"].to(device)
    embedding = model.get_image_features(image)
    embedding_as_np = embedding.cpu().detach().numpy()
	
    return embedding_as_np


def frames_embeddings(video_path):
    """ This function returns all the embeddings associated to a video """
    all_embeddings = []
    
    video_obj = cv2.VideoCapture(video_path)
    #print("video_obj", video_obj)


    fps = video_obj.get(cv2.CAP_PROP_FPS)
    interval_factor = 3 
    frame_interval = int(fps / interval_factor)
    
    frame_count = 0 
    saved_count = 0 
    
    while True: 
        success, frame = video_obj.read()
        if not success: 
            break

        if frame_count % frame_interval == 0:
            single_frame_embedding = get_single_image_embedding(frame)
            all_embeddings.append(single_frame_embedding)   
            # Clear memory (important step to avoid running out of memory)
            torch.cuda.empty_cache()
            saved_count+=1
        
        frame_count +=1

    video_obj.release()

    #return np.array(all_embeddings).squeeze(axis=1)
    #print("saved_count", saved_count)
    #print("frame_count", frame_count)
    return np.array(all_embeddings).squeeze(1)
    
        
video_path = "/kaggle/input/msrvttqa/archive/TrainValVideo/video1.mp4"
frames = frames_embeddings(video_path)
print("frames", frames.shape)   
# (num_frames, batch, embedding_size)    # the embedding_size is determined by model.get_image_features
# Out:
# frames (69, 512)

# %% [markdown]
# ### **4. MSRVTT Text Encoder**

# %% [markdown]
# ### **4.1 Defining Tokenizer**

# %%
# Load a pre-trained model of Bert and download the vocabulary
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased")

# Example on what does the Tokenizer do -> The Tokenizer outputs 'input_ids', 'token_type_ids', 'attention_mask'
# to use the Tokenizer to transform the text into token representation
#tokenizer("Hello, this is a sentence!", "And this sentence goes with it.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ### **4.2 Defining MultipleChoiceDataset for Text Input**

# %%
class MultipleChoiceDataset(Dataset):
    def __init__(self, dataset, tokenizer, options, max_length=None, padding=True):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.options = options
        self.max_length = max_length
        self.padding = padding
        self.encoded_data = self.preprocess_function()

    def preprocess_function(self):
        processed_examples = []
        for example in self.dataset:
            # Prepare the first sentence (the context) repeated for each option
            #print("example[question]", example)
            first_sentences = [example["question"]] * len(self.options)
            second_sentences = [example[option] for option in self.options]
            
            # Debugging: Print first_sentences and second_sentences types and contents
            #print("first_sentences", type(first_sentences), first_sentences)
            #print("second_sentences", type(second_sentences), second_sentences)
            
            # Tokenize
            tokenized = self.tokenizer(
                first_sentences, second_sentences, 
                padding="max_length", 
                truncation=True, 
                max_length=self.max_length, 
                return_tensors="pt"
            )

            # Convert tokenized inputs to tensors and add to the processed data
            processed_examples.append({
                "input_ids": tokenized["input_ids"],
                "attention_mask": tokenized["attention_mask"],
                "label": int(example["label"])  # Ensure the label is an integer
            })
        return processed_examples
    
    def __len__(self):
        return len(self.encoded_data)

    
    def __getitem__(self, idx):
        #print(f"Indices passed to __getitem__: {idx}")
        if isinstance(idx, list):  # If a batch of indices is passed
            batch = [self.encoded_data[i] for i in idx]
            #print("batch", batch)
            input_ids = torch.stack([item["input_ids"].squeeze(0) for item in batch])
            attention_mask = torch.stack([item["attention_mask"].squeeze(0) for item in batch])
            labels = torch.tensor([item["label"] for item in batch], dtype=torch.long)
            return {
                "input_ids": input_ids,
                "attention_mask": attention_mask,
                "label": labels,
            }
        else:  # If a single index is passed
            return {
                "input_ids": self.encoded_data[idx]["input_ids"].squeeze(0),  # Remove the batch dimension
                "attention_mask": self.encoded_data[idx]["attention_mask"].squeeze(0),
                "label": torch.tensor(self.encoded_data[idx]["label"], dtype=torch.long),  # Convert to long tensor
            }

#max_length = 128 
#options = ["a1", "a2", "a3", "a4", "a5"]  # Specify your options here

# Assuming 'datasets' is your input dataset, and 'tokenizer' is the initialized tokenizer

#datasets = Dataset.from_pandas(last_msrvtt)
#datasets = datasets.rename_column("answer", "label")
#print("datasets",datasets)
#print("datasets[0]",datasets[0])
            
#print(type(datasets))
#dataset = MultipleChoiceDataset(datasets, tokenizer, options, max_length=max_length)
#print(len(dataset))   # 2000 -> we have 2000 questions 
#sample = dataset[1]
#print(sample)
#sample = datasets[0]
#print("sample", sample)
#dataset = MultipleChoiceDataset([sample], tokenizer, options, max_length = max_length)
#print("dataset", dataset[0])

# %%
''' 
datasets = Dataset.from_pandas(last_msrvtt)
# Testing the class with your dataset
max_length = 128 
options = ["a1", "a2", "a3", "a4", "a5"]  # Specify your options here

# Assuming 'datasets' is your input dataset, and 'tokenizer' is the initialized tokenizer
print(type(datasets))
dataset = MultipleChoiceDataset(datasets, tokenizer, options, max_length=max_length)

# Access a sample to see the output
sample = dataset[1]
print(sample)
print(len(dataset))


# Create DataLoader without using collate_fn
batch_size = 8 
train_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
print(len(train_dataloader))
#val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)



for batch_idx, batch in enumerate(train_dataloader):
    print("Input IDs:", batch["input_ids"].shape, batch["input_ids"])
    print("Attention Mask:", batch["attention_mask"].shape, batch["attention_mask"])
    print("Labels:", batch["label"].shape, batch["label"])
    break  # To get only the first batch
'''
# Out:
# ' \ndatasets = Dataset.from_pandas(last_msrvtt)\n# Testing the class with your dataset\nmax_length = 128 \noptions = ["a1", "a2", "a3", "a4", "a5"]  # Specify your options here\n\n# Assuming \'datasets\' is your input dataset, and \'tokenizer\' is the initialized tokenizer\nprint(type(datasets))\ndataset = MultipleChoiceDataset(datasets, tokenizer, options, max_length=max_length)\n\n# Access a sample to see the output\nsample = dataset[1]\nprint(sample)\nprint(len(dataset))\n\n\n# Create DataLoader without using collate_fn\nbatch_size = 8 \ntrain_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)\nprint(len(train_dataloader))\n#val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)\n\n\n\nfor batch_idx, batch in enumerate(train_dataloader):\n    print("Input IDs:", batch["input_ids"].shape, batch["input_ids"])\n    print("Attention Mask:", batch["attention_mask"].shape, batch["attention_mask"])\n    print("Labels:", batch["label"].shape, batch["label"])\n    break  # To get only the first batch\n'

# %%
#for batch_idx, batch in enumerate(train_dataloader):
#    print(f"Batch {batch_idx}:")
#    print("Input IDs:", batch["input_ids"])
#    print("Attention Mask:", batch["attention_mask"])
#    print("Labels:", batch["label"])

# %%
# Decode the input IDs to see the original text   -> 
#decoded_input = tokenizer.decode(sample['input_ids'][0], skip_special_tokens=True)
#print("Decoded Input:", decoded_input)

# %% [markdown]
# #### **4.2 EncTextNew and CrossAttention, out.shape [batch_size*num_choice, seq_len, embed_bert]**

# %%
class EncTxtNew(torch.nn.Module):
    def __init__(self, bert_checkpoint, hidden_size, num_attention_heads):
        super().__init__()

        self.bert_checkpoint = bert_checkpoint
        self.hidden_size = hidden_size 
        self.num_attention_heads = num_attention_heads 
        bert = transformers.AutoModel.from_pretrained(bert_checkpoint)
        self.emb_txt = bert.embeddings
        self.txt_trsfr = bert.encoder
        self.mask_ext = bert.get_extended_attention_mask
        self.size_vocab = bert.config.vocab_size
        del bert

        self.initialize_weights()

    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                if module.bias is not None:
                    nn.init.zeros_(module.bias)
            elif isinstance(module, nn.Embedding):
                nn.init.normal_(module.weight, mean=0.0, std=0.02)
            elif isinstance(module, nn.LayerNorm):
                nn.init.ones_(module.weight)
                nn.init.zeros_(module.bias)

    def get_attn_mask(self, mask_txt, attn_mask_type="full"):
        # Using full attention and not "seq2seq" attention_mask_type
        return mask_txt
        
    def forward(self, questions, answers, mask_questions=None, mask_answers=None, token_type_ids=None, position_ids=None, attn_mask_type="full"):
        #print("questions", questions.shape)
        #print("answers", answers.shape)
        #print("mask_questions init", mask_questions.shape)
        #print("mask_answers init", mask_answers.shape)
        batch_size = questions.size(0)
        
        # Flatten the input for multiple choices
        questions = questions[:1].view(-1, questions.size(-1))  # Take only one question
        #print("questions after slicing", questions.shape)
        answers = answers.view(-1, answers.size(-1))  # Flatten answers
        #print("answers after view", answers.shape)
        
        # Flatten other tensors if they exist
        mask_questions = mask_questions[:1].view(-1, mask_questions.size(-1)) if mask_questions is not None else None
        #print("mask_questions", mask_questions.shape)
        mask_answers = mask_answers.view(-1, mask_answers.size(-1)) if mask_answers is not None else None
        #print("mask_answers", mask_answers.shape)
        token_type_ids = token_type_ids.view(-1, token_type_ids.size(-1)) if token_type_ids is not None else None
        position_ids = position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
        
        # Encode questions
        f_questions = self.emb_txt(questions, token_type_ids=token_type_ids, position_ids=position_ids)
        #print("f_questions", f_questions.shape)
        
        if self.txt_trsfr is not None:
            mask_questions = mask_questions if mask_questions is not None else torch.ones_like(questions)
            #print("mask_questions", mask_questions.shape)
            
            m_questions = self.get_attn_mask(mask_questions, attn_mask_type)
            #print("m_questions get_attn_mask", m_questions.shape)

            m_questions = self.mask_ext(m_questions, m_questions.shape, m_questions.device)
            #print("m_questions_mask_ext", m_questions.shape)
            
            m_questions = m_questions.to(dtype=f_questions.dtype, device=f_questions.device)
            
            f_questions = self.txt_trsfr(f_questions, m_questions, output_attentions=False)['last_hidden_state']
            #print("f_questions after bert.encoder", f_questions.shape)
    
        # Repeat for answers
        f_answers = self.emb_txt(answers)
        #print("f_answers", f_answers.shape)
        
        if self.txt_trsfr is not None:
            mask_answers = mask_answers if mask_answers is not None else torch.ones_like(answers)
            #print("mask_answers", mask_answers.shape)
            
            m_answers = self.get_attn_mask(mask_answers, attn_mask_type)
            #print("m_answers get_attn_mask", m_answers.shape)

            m_answers = self.mask_ext(m_answers, m_answers.shape, m_answers.device)
            #print("m_answers_mask_ext", m_answers.shape)
            
            m_answers = m_answers.to(dtype=f_answers.dtype, device=f_answers.device)
            
            f_answers = self.txt_trsfr(f_answers, m_answers, output_attentions=False)['last_hidden_state']
            #print("f_answers after bert.encoder", f_answers.shape)
        
        return f_questions, f_answers

# %%
datasets = Dataset.from_pandas(last_msrvtt)
datasets = datasets.rename_column("answer", "label")

print("datasets",datasets)
print("datasets[0]",datasets[0])
pd_datasets = datasets.to_pandas()
# pd_datasets

# Assuming your DataFrame is named df
first_20_rows = pd_datasets.iloc[:20]
#first_20_rows
# Out:
# datasets Dataset({
#     features: ['title', 'id', 'clip_name', 'question', 'a1', 'a2', 'a3', 'a4', 'a5', 'label'],
#     num_rows: 2000
# })
# datasets[0] {'title': 'msr143897', 'id': 'mc0', 'clip_name': 'video9770', 'question': 'person connecting something system', 'a1': 'boy trying fix problem', 'a2': 'movie trailer shows various scenes movie', 'a3': 'asian man discusses technology younger generations', 'a4': 'two men wave runner ocean rescuing surfer', 'a5': 'group dancing', 'label': '0'}

# %%
datasets = Dataset.from_pandas(last_msrvtt)
datasets = datasets.rename_column("answer", "label")

print("datasets",datasets)
print("datasets[0]",datasets[0])
pd_datasets = datasets.to_pandas()

train_df, test_df = train_test_split(pd_datasets, test_size=0.4, random_state=42)
#val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

print(type(train_df))
print(len(train_df))
print(len(test_df))
#print(len(val_df))
# Out:
# datasets Dataset({
#     features: ['title', 'id', 'clip_name', 'question', 'a1', 'a2', 'a3', 'a4', 'a5', 'label'],
#     num_rows: 2000
# })
# datasets[0] {'title': 'msr143897', 'id': 'mc0', 'clip_name': 'video9770', 'question': 'person connecting something system', 'a1': 'boy trying fix problem', 'a2': 'movie trailer shows various scenes movie', 'a3': 'asian man discusses technology younger generations', 'a4': 'two men wave runner ocean rescuing surfer', 'a5': 'group dancing', 'label': '0'}
# <class 'pandas.core.frame.DataFrame'>
# 1200
# 800

# %% [markdown]
# ### **5. Matchy Dataset**

# %%
# Passing questions as questions and answers as values 
# -> text_embedding.shape = [batch_size * num_choices, variable_query_tokens_len, 768]
def MatchyDataset(dict_dataset, model_txt, model_clip, processor, tokenizer, options, max_length, device, output_file):
    model_txt.eval()
    model_clip.eval()

    matchy_dataset = []
    for i in range(len(dict_dataset)):
        print("Processing sample", i)
        sample = dict_dataset.iloc[i].to_dict()  # Convert row to dictionary

        video_path = os.path.join("/kaggle/input/video-nlp/msrvtt_video/", sample['clip_name'] + ".mp4")
        
        sample_dataset = MultipleChoiceDataset([sample], tokenizer, options, max_length=max_length)

        input_ids = sample_dataset[0]["input_ids"].to(device)  # [batch_size, num_choices, max_length]
        #print("input_ids multiple choice dataset", input_ids.shape)
        attention_mask = sample_dataset[0]["attention_mask"].to(device)
        #print("attention_mask multiple choice dataset", attention_mask.shape)
        labels = sample_dataset[0]["label"].to(device)
        #print("labels multiple choice dataset", labels.shape)

        # Reshape for multiple choices
        input_ids = input_ids.view(-1, max_length)  # [batch_size * num_choices, max_length]
        #print("input_ids reshaping", input_ids.shape)
        attention_mask = attention_mask.view(-1, max_length)  # Same shape adjustment
        #print("attention mask reshaping", attention_mask.shape)
        
        # Split into questions (question tokens) and answers (answer tokens)
        sep_token_id = tokenizer.sep_token_id  # Get the ID for the [SEP] token
        #print("sep_token_id", sep_token_id)
        questions, answers = [], []
        questions_mask, answers_mask = [], []

        for idx in range(input_ids.size(0)):
            input_row = input_ids[idx]
            mask_row = attention_mask[idx]

            # Find the position of the first [SEP]
            sep_index = (input_row == sep_token_id).nonzero(as_tuple=True)[0][0].item()

            # Extract question (query) and answer (keys/values) tokens
            question_tokens = input_row[:sep_index]  # Tokens before the first [SEP]
            answer_tokens = input_row[sep_index + 1:]  # Tokens after the first [SEP]

            # Create attention masks
            question_mask = mask_row[:sep_index]
            answer_mask = mask_row[sep_index + 1:]

            # Append to lists (pad to maintain max_length)
            questions.append(question_tokens)
            answers.append(answer_tokens)
            questions_mask.append(question_mask)
            answers_mask.append(answer_mask)

        # Pad sequences to max_length
        questions = torch.nn.utils.rnn.pad_sequence(questions, batch_first=True, padding_value=0).to(device)
        answers = torch.nn.utils.rnn.pad_sequence(answers, batch_first=True, padding_value=0).to(device)
        questions_mask = torch.nn.utils.rnn.pad_sequence(questions_mask, batch_first=True, padding_value=0).to(device)
        answers_mask = torch.nn.utils.rnn.pad_sequence(answers_mask, batch_first=True, padding_value=0).to(device)
        #print("questions", questions)
        #print("answers", answers)
        #print("questions_mask", questions_mask)
        #print("answers_mask", answers_mask)
        
        # Process with the text model
        with torch.no_grad():
            questions_embeddings, answers_embeddings = model_txt(
                questions=questions,
                answers=answers,
                mask_questions=questions_mask,
                mask_answers=answers_mask
            )
            video_embeddings = frames_embeddings(video_path)  # Process video embeddings
        #print("text_embeddings", text_embeddings.shape)
        #print("video_embeddings", video_embeddings.shape)
        #print("label", labels)
        # Add to dataset
        matchy_dataset.append({
            "questions_embeddings" : questions_embeddings.detach().cpu(), 
            "answers_embeddings" : answers_embeddings.detach().cpu(),
            "video_embeddings": torch.tensor(video_embeddings, dtype=torch.float).detach().cpu(),
            "label": labels.detach().cpu()
        })

        # Save matchy_dataset to a pickle file
        output = os.path.join("/kaggle/working/", output_file)
        with open(output, 'wb') as f:
            pickle.dump(matchy_dataset, f)

    return matchy_dataset

# %%
# Testing Matchy Dataset
device = "cuda" if torch.cuda.is_available() else "cpu"
bert_checkpoint = "bert-base-uncased"
max_length = 128
options = ["a1", "a2", "a3", "a4", "a5"]
num_choices = len(options)
hidden_size = 768 
num_attention_heads = 12 

# Load CLIP model and processor from Hugging Face
model_clip = CLIPModel.from_pretrained("openai/clip-vit-base-patch16").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")
model_txt = EncTxtNew(bert_checkpoint, hidden_size, num_attention_heads).to(device)

matchy_train = MatchyDataset(train_df, model_txt, model_clip, processor, tokenizer, options, max_length, device, output_file = "train_df.pkl")
matchy_test = MatchyDataset(test_df, model_txt, model_clip, processor, tokenizer, options, max_length, device, output_file = "test_df.pkl")
#matchy_val = MatchyDataset(val_df, model_txt, model_clip, processor, tokenizer, options, max_length, device, output_file = "test_df.pkl")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Processing sample 0
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:1126: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Processing sample 1
# Processing sample 2
# Processing sample 3
# Processing sample 4
# Processing sample 5
# Processing sample 6
# Processing sample 7
# Processing sample 8
# Processing sample 9
# Processing sample 10
# Processing sample 11
# Processing sample 12
# Processing sample 13
# Processing sample 14
# Processing sample 15
# Processing sample 16
# Processing sample 17
# Processing sample 18
# Processing sample 19
# Processing sample 20
# Processing sample 21
# Processing sample 22
# Processing sample 23
# Processing sample 24
# Processing sample 25
# Processing sample 26
# Processing sample 27
# Processing sample 28
# Processing sample 29
# Processing sample 30
# Processing sample 31
# Processing sample 32
# Processing sample 33
# Processing sample 34
# Processing sample 35
# Processing sample 36
# Processing sample 37
# Processing sample 38
# Processing sample 39
# Processing sample 40
# Processing sample 41
# Processing sample 42
# Processing sample 43
# Processing sample 44
# Processing sample 45
# Processing sample 46
# Processing sample 47
# Processing sample 48
# Processing sample 49
# Processing sample 50
# Processing sample 51
# Processing sample 52
# Processing sample 53
# Processing sample 54
# Processing sample 55
# Processing sample 56
# Processing sample 57
# Processing sample 58
# Processing sample 59
# Processing sample 60
# Processing sample 61
# Processing sample 62
# Processing sample 63
# Processing sample 64
# Processing sample 65
# Processing sample 66
# Processing sample 67
# Processing sample 68
# Processing sample 69
# Processing sample 70
# Processing sample 71
# Processing sample 72
# Processing sample 73
# Processing sample 74
# Processing sample 75
# Processing sample 76
# Processing sample 77
# Processing sample 78
# Processing sample 79
# Processing sample 80
# Processing sample 81
# Processing sample 82
# Processing sample 83
# Processing sample 84
# Processing sample 85
# Processing sample 86
# Processing sample 87
# Processing sample 88
# Processing sample 89
# Processing sample 90
# Processing sample 91
# Processing sample 92
# Processing sample 93
# Processing sample 94
# Processing sample 95
# Processing sample 96
# Processing sample 97
# Processing sample 98
# Processing sample 99
# Processing sample 100
# Processing sample 101
# Processing sample 102
# Processing sample 103
# Processing sample 104
# Processing sample 105
# Processing sample 106
# Processing sample 107
# Processing sample 108
# Processing sample 109
# Processing sample 110
# Processing sample 111
# Processing sample 112
# Processing sample 113
# Processing sample 114
# Processing sample 115
# Processing sample 116
# Processing sample 117
# Processing sample 118
# Processing sample 119
# Processing sample 120
# Processing sample 121
# Processing sample 122
# Processing sample 123
# Processing sample 124
# Processing sample 125
# Processing sample 126
# Processing sample 127
# Processing sample 128
# Processing sample 129
# Processing sample 130
# Processing sample 131
# Processing sample 132
# Processing sample 133
# Processing sample 134
# Processing sample 135
# Processing sample 136
# Processing sample 137
# Processing sample 138
# Processing sample 139
# Processing sample 140
# Processing sample 141
# Processing sample 142
# Processing sample 143
# Processing sample 144
# Processing sample 145
# Processing sample 146
# Processing sample 147
# Processing sample 148
# Processing sample 149
# Processing sample 150
# Processing sample 151
# Processing sample 152
# Processing sample 153
# Processing sample 154
# Processing sample 155
# Processing sample 156
# Processing sample 157
# Processing sample 158
# Processing sample 159
# Processing sample 160
# Processing sample 161
# Processing sample 162
# Processing sample 163
# Processing sample 164
# Processing sample 165
# Processing sample 166
# Processing sample 167
# Processing sample 168
# Processing sample 169
# Processing sample 170
# Processing sample 171
# Processing sample 172
# Processing sample 173
# Processing sample 174
# Processing sample 175
# Processing sample 176
# Processing sample 177
# Processing sample 178
# Processing sample 179
# Processing sample 180
# Processing sample 181
# Processing sample 182
# Processing sample 183
# Processing sample 184
# Processing sample 185
# Processing sample 186
# Processing sample 187
# Processing sample 188
# Processing sample 189
# Processing sample 190
# Processing sample 191
# Processing sample 192
# Processing sample 193
# Processing sample 194
# Processing sample 195
# Processing sample 196
# Processing sample 197
# Processing sample 198
# Processing sample 199
# Processing sample 200
# Processing sample 201
# Processing sample 202
# Processing sample 203
# Processing sample 204
# Processing sample 205
# Processing sample 206
# Processing sample 207
# Processing sample 208
# Processing sample 209
# Processing sample 210
# Processing sample 211
# Processing sample 212
# Processing sample 213
# Processing sample 214
# Processing sample 215
# Processing sample 216
# Processing sample 217
# Processing sample 218
# Processing sample 219
# Processing sample 220
# Processing sample 221
# Processing sample 222
# Processing sample 223
# Processing sample 224
# Processing sample 225
# Processing sample 226
# Processing sample 227
# Processing sample 228
# Processing sample 229
# Processing sample 230
# Processing sample 231
# Processing sample 232
# Processing sample 233
# Processing sample 234
# Processing sample 235
# Processing sample 236
# Processing sample 237
# Processing sample 238
# Processing sample 239
# Processing sample 240
# Processing sample 241
# Processing sample 242
# Processing sample 243
# Processing sample 244
# Processing sample 245
# Processing sample 246
# Processing sample 247
# Processing sample 248
# Processing sample 249
# Processing sample 250
# Processing sample 251
# Processing sample 252
# Processing sample 253
# Processing sample 254
# Processing sample 255
# Processing sample 256
# Processing sample 257
# Processing sample 258
# Processing sample 259
# Processing sample 260
# Processing sample 261
# Processing sample 262
# Processing sample 263
# Processing sample 264
# Processing sample 265
# Processing sample 266
# Processing sample 267
# Processing sample 268
# Processing sample 269
# Processing sample 270
# Processing sample 271
# Processing sample 272
# Processing sample 273
# Processing sample 274
# Processing sample 275
# Processing sample 276
# Processing sample 277
# Processing sample 278
# Processing sample 279
# Processing sample 280
# Processing sample 281
# Processing sample 282
# Processing sample 283
# Processing sample 284
# Processing sample 285
# Processing sample 286
# Processing sample 287
# Processing sample 288
# Processing sample 289
# Processing sample 290
# Processing sample 291
# Processing sample 292
# Processing sample 293
# Processing sample 294
# Processing sample 295
# Processing sample 296
# Processing sample 297
# Processing sample 298
# Processing sample 299
# Processing sample 300
# Processing sample 301
# Processing sample 302
# Processing sample 303
# Processing sample 304
# Processing sample 305
# Processing sample 306
# Processing sample 307
# Processing sample 308
# Processing sample 309
# Processing sample 310
# Processing sample 311
# Processing sample 312
# Processing sample 313
# Processing sample 314
# Processing sample 315
# Processing sample 316
# Processing sample 317
# Processing sample 318
# Processing sample 319
# Processing sample 320
# Processing sample 321
# Processing sample 322
# Processing sample 323
# Processing sample 324
# Processing sample 325
# Processing sample 326
# Processing sample 327
# Processing sample 328
# Processing sample 329
# Processing sample 330
# Processing sample 331
# Processing sample 332
# Processing sample 333
# Processing sample 334
# Processing sample 335
# Processing sample 336
# Processing sample 337
# Processing sample 338
# Processing sample 339
# Processing sample 340
# Processing sample 341
# Processing sample 342
# Processing sample 343
# Processing sample 344
# Processing sample 345
# Processing sample 346
# Processing sample 347
# Processing sample 348
# Processing sample 349
# Processing sample 350
# Processing sample 351
# Processing sample 352
# Processing sample 353
# Processing sample 354
# Processing sample 355
# Processing sample 356
# Processing sample 357
# Processing sample 358
# Processing sample 359
# Processing sample 360
# Processing sample 361
# Processing sample 362
# Processing sample 363
# Processing sample 364
# Processing sample 365
# Processing sample 366
# Processing sample 367
# Processing sample 368
# Processing sample 369
# Processing sample 370
# Processing sample 371
# Processing sample 372
# Processing sample 373
# Processing sample 374
# Processing sample 375
# Processing sample 376
# Processing sample 377
# Processing sample 378
# Processing sample 379
# Processing sample 380
# Processing sample 381
# Processing sample 382
# Processing sample 383
# Processing sample 384
# Processing sample 385
# Processing sample 386
# Processing sample 387
# Processing sample 388
# Processing sample 389
# Processing sample 390
# Processing sample 391
# Processing sample 392
# Processing sample 393
# Processing sample 394
# Processing sample 395
# Processing sample 396
# Processing sample 397
# Processing sample 398
# Processing sample 399
# Processing sample 400
# Processing sample 401
# Processing sample 402
# Processing sample 403
# Processing sample 404
# Processing sample 405
# Processing sample 406
# Processing sample 407
# Processing sample 408
# Processing sample 409
# Processing sample 410
# Processing sample 411
# Processing sample 412
# Processing sample 413
# Processing sample 414
# Processing sample 415
# Processing sample 416
# Processing sample 417
# Processing sample 418
# Processing sample 419
# Processing sample 420
# Processing sample 421
# Processing sample 422
# Processing sample 423
# Processing sample 424
# Processing sample 425
# Processing sample 426
# Processing sample 427
# Processing sample 428
# Processing sample 429
# Processing sample 430
# Processing sample 431
# Processing sample 432
# Processing sample 433
# Processing sample 434
# Processing sample 435
# Processing sample 436
# Processing sample 437
# Processing sample 438
# Processing sample 439
# Processing sample 440
# Processing sample 441
# Processing sample 442
# Processing sample 443
# Processing sample 444
# Processing sample 445
# Processing sample 446
# Processing sample 447
# Processing sample 448
# Processing sample 449
# Processing sample 450
# Processing sample 451
# Processing sample 452
# Processing sample 453
# Processing sample 454
# Processing sample 455
# Processing sample 456
# Processing sample 457
# Processing sample 458
# Processing sample 459
# Processing sample 460
# Processing sample 461
# Processing sample 462
# Processing sample 463
# Processing sample 464
# Processing sample 465
# Processing sample 466
# Processing sample 467
# Processing sample 468
# Processing sample 469
# Processing sample 470
# Processing sample 471
# Processing sample 472
# Processing sample 473
# Processing sample 474
# Processing sample 475
# Processing sample 476
# Processing sample 477
# Processing sample 478
# Processing sample 479
# Processing sample 480
# Processing sample 481
# Processing sample 482
# Processing sample 483
# Processing sample 484
# Processing sample 485
# Processing sample 486
# Processing sample 487
# Processing sample 488
# Processing sample 489
# Processing sample 490
# Processing sample 491
# Processing sample 492
# Processing sample 493
# Processing sample 494
# Processing sample 495
# Processing sample 496
# Processing sample 497
# Processing sample 498
# Processing sample 499
# Processing sample 500
# Processing sample 501
# Processing sample 502
# Processing sample 503
# Processing sample 504
# Processing sample 505
# Processing sample 506
# Processing sample 507
# Processing sample 508
# Processing sample 509
# Processing sample 510
# Processing sample 511
# Processing sample 512
# Processing sample 513
# Processing sample 514
# Processing sample 515
# Processing sample 516
# Processing sample 517
# Processing sample 518
# Processing sample 519
# Processing sample 520
# Processing sample 521
# Processing sample 522
# Processing sample 523
# Processing sample 524
# Processing sample 525
# Processing sample 526
# Processing sample 527
# Processing sample 528
# Processing sample 529
# Processing sample 530
# Processing sample 531
# Processing sample 532
# Processing sample 533
# Processing sample 534
# Processing sample 535
# Processing sample 536
# Processing sample 537
# Processing sample 538
# Processing sample 539
# Processing sample 540
# Processing sample 541
# Processing sample 542
# Processing sample 543
# Processing sample 544
# Processing sample 545
# Processing sample 546
# Processing sample 547
# Processing sample 548
# Processing sample 549
# Processing sample 550
# Processing sample 551
# Processing sample 552
# Processing sample 553
# Processing sample 554
# Processing sample 555
# Processing sample 556
# Processing sample 557
# Processing sample 558
# Processing sample 559
# Processing sample 560
# Processing sample 561
# Processing sample 562
# Processing sample 563
# Processing sample 564
# Processing sample 565
# Processing sample 566
# Processing sample 567
# Processing sample 568
# Processing sample 569
# Processing sample 570
# Processing sample 571
# Processing sample 572
# Processing sample 573
# Processing sample 574
# Processing sample 575
# Processing sample 576
# Processing sample 577
# Processing sample 578
# Processing sample 579
# Processing sample 580
# Processing sample 581
# Processing sample 582
# Processing sample 583
# Processing sample 584
# Processing sample 585
# Processing sample 586
# Processing sample 587
# Processing sample 588
# Processing sample 589
# Processing sample 590
# Processing sample 591
# Processing sample 592
# Processing sample 593
# Processing sample 594
# Processing sample 595
# Processing sample 596
# Processing sample 597
# Processing sample 598
# Processing sample 599
# Processing sample 600
# Processing sample 601
# Processing sample 602
# Processing sample 603
# Processing sample 604
# Processing sample 605
# Processing sample 606
# Processing sample 607
# Processing sample 608
# Processing sample 609
# Processing sample 610
# Processing sample 611
# Processing sample 612
# Processing sample 613
# Processing sample 614
# Processing sample 615
# Processing sample 616
# Processing sample 617
# Processing sample 618
# Processing sample 619
# Processing sample 620
# Processing sample 621
# Processing sample 622
# Processing sample 623
# Processing sample 624
# Processing sample 625
# Processing sample 626
# Processing sample 627
# Processing sample 628
# Processing sample 629
# Processing sample 630
# Processing sample 631
# Processing sample 632
# Processing sample 633
# Processing sample 634
# Processing sample 635
# Processing sample 636
# Processing sample 637
# Processing sample 638
# Processing sample 639
# Processing sample 640
# Processing sample 641
# Processing sample 642
# Processing sample 643
# Processing sample 644
# Processing sample 645
# Processing sample 646
# Processing sample 647
# Processing sample 648
# Processing sample 649
# Processing sample 650
# Processing sample 651
# Processing sample 652
# Processing sample 653
# Processing sample 654
# Processing sample 655
# Processing sample 656
# Processing sample 657
# Processing sample 658
# Processing sample 659
# Processing sample 660
# Processing sample 661
# Processing sample 662
# Processing sample 663
# Processing sample 664
# Processing sample 665
# Processing sample 666
# Processing sample 667
# Processing sample 668
# Processing sample 669
# Processing sample 670
# Processing sample 671
# Processing sample 672
# Processing sample 673
# Processing sample 674
# Processing sample 675
# Processing sample 676
# Processing sample 677
# Processing sample 678
# Processing sample 679
# Processing sample 680
# Processing sample 681
# Processing sample 682
# Processing sample 683
# Processing sample 684
# Processing sample 685
# Processing sample 686
# Processing sample 687
# Processing sample 688
# Processing sample 689
# Processing sample 690
# Processing sample 691
# Processing sample 692
# Processing sample 693
# Processing sample 694
# Processing sample 695
# Processing sample 696
# Processing sample 697
# Processing sample 698
# Processing sample 699
# Processing sample 700
# Processing sample 701
# Processing sample 702
# Processing sample 703
# Processing sample 704
# Processing sample 705
# Processing sample 706
# Processing sample 707
# Processing sample 708
# Processing sample 709
# Processing sample 710
# Processing sample 711
# Processing sample 712
# Processing sample 713
# Processing sample 714
# Processing sample 715
# Processing sample 716
# Processing sample 717
# Processing sample 718
# Processing sample 719
# Processing sample 720
# Processing sample 721
# Processing sample 722
# Processing sample 723
# Processing sample 724
# Processing sample 725
# Processing sample 726
# Processing sample 727
# Processing sample 728
# Processing sample 729
# Processing sample 730
# Processing sample 731
# Processing sample 732
# Processing sample 733
# Processing sample 734
# Processing sample 735
# Processing sample 736
# Processing sample 737
# Processing sample 738
# Processing sample 739
# Processing sample 740
# Processing sample 741
# Processing sample 742
# Processing sample 743
# Processing sample 744
# Processing sample 745
# Processing sample 746
# Processing sample 747
# Processing sample 748
# Processing sample 749
# Processing sample 750
# Processing sample 751
# Processing sample 752
# Processing sample 753
# Processing sample 754
# Processing sample 755
# Processing sample 756
# Processing sample 757
# Processing sample 758
# Processing sample 759
# Processing sample 760
# Processing sample 761
# Processing sample 762
# Processing sample 763
# Processing sample 764
# Processing sample 765
# Processing sample 766
# Processing sample 767
# Processing sample 768
# Processing sample 769
# Processing sample 770
# Processing sample 771
# Processing sample 772
# Processing sample 773
# Processing sample 774
# Processing sample 775
# Processing sample 776
# Processing sample 777
# Processing sample 778
# Processing sample 779
# Processing sample 780
# Processing sample 781
# Processing sample 782
# Processing sample 783
# Processing sample 784
# Processing sample 785
# Processing sample 786
# Processing sample 787
# Processing sample 788
# Processing sample 789
# Processing sample 790
# Processing sample 791
# Processing sample 792
# Processing sample 793
# Processing sample 794
# Processing sample 795
# Processing sample 796
# Processing sample 797
# Processing sample 798
# Processing sample 799
# Processing sample 800
# Processing sample 801
# Processing sample 802
# Processing sample 803
# Processing sample 804
# Processing sample 805
# Processing sample 806
# Processing sample 807
# Processing sample 808
# Processing sample 809
# Processing sample 810
# Processing sample 811
# Processing sample 812
# Processing sample 813
# Processing sample 814
# Processing sample 815
# Processing sample 816
# Processing sample 817
# Processing sample 818
# Processing sample 819
# Processing sample 820
# Processing sample 821
# Processing sample 822
# Processing sample 823
# Processing sample 824
# Processing sample 825
# Processing sample 826
# Processing sample 827
# Processing sample 828
# Processing sample 829
# Processing sample 830
# Processing sample 831
# Processing sample 832
# Processing sample 833
# Processing sample 834
# Processing sample 835
# Processing sample 836
# Processing sample 837
# Processing sample 838
# Processing sample 839
# Processing sample 840
# Processing sample 841
# Processing sample 842
# Processing sample 843
# Processing sample 844
# Processing sample 845
# Processing sample 846
# Processing sample 847
# Processing sample 848
# Processing sample 849
# Processing sample 850
# Processing sample 851
# Processing sample 852
# Processing sample 853
# Processing sample 854
# Processing sample 855
# Processing sample 856
# Processing sample 857
# Processing sample 858
# Processing sample 859
# Processing sample 860
# Processing sample 861
# Processing sample 862
# Processing sample 863
# Processing sample 864
# Processing sample 865
# Processing sample 866
# Processing sample 867
# Processing sample 868
# Processing sample 869
# Processing sample 870
# Processing sample 871
# Processing sample 872
# Processing sample 873
# Processing sample 874
# Processing sample 875
# Processing sample 876
# Processing sample 877
# Processing sample 878
# Processing sample 879
# Processing sample 880
# Processing sample 881
# Processing sample 882
# Processing sample 883
# Processing sample 884
# Processing sample 885
# Processing sample 886
# Processing sample 887
# Processing sample 888
# Processing sample 889
# Processing sample 890
# Processing sample 891
# Processing sample 892
# Processing sample 893
# Processing sample 894
# Processing sample 895
# Processing sample 896
# Processing sample 897
# Processing sample 898
# Processing sample 899
# Processing sample 900
# Processing sample 901
# Processing sample 902
# Processing sample 903
# Processing sample 904
# Processing sample 905
# Processing sample 906
# Processing sample 907
# Processing sample 908
# Processing sample 909
# Processing sample 910
# Processing sample 911
# Processing sample 912
# Processing sample 913
# Processing sample 914
# Processing sample 915
# Processing sample 916
# Processing sample 917
# Processing sample 918
# Processing sample 919
# Processing sample 920
# Processing sample 921
# Processing sample 922
# Processing sample 923
# Processing sample 924
# Processing sample 925
# Processing sample 926
# Processing sample 927
# Processing sample 928
# Processing sample 929
# Processing sample 930
# Processing sample 931
# Processing sample 932
# Processing sample 933
# Processing sample 934
# Processing sample 935
# Processing sample 936
# Processing sample 937
# Processing sample 938
# Processing sample 939
# Processing sample 940
# Processing sample 941
# Processing sample 942
# Processing sample 943
# Processing sample 944
# Processing sample 945
# Processing sample 946
# Processing sample 947
# Processing sample 948
# Processing sample 949
# Processing sample 950
# Processing sample 951
# Processing sample 952
# Processing sample 953
# Processing sample 954
# Processing sample 955
# Processing sample 956
# Processing sample 957
# Processing sample 958
# Processing sample 959
# Processing sample 960
# Processing sample 961
# Processing sample 962
# Processing sample 963
# Processing sample 964
# Processing sample 965
# Processing sample 966
# Processing sample 967
# Processing sample 968
# Processing sample 969
# Processing sample 970
# Processing sample 971
# Processing sample 972
# Processing sample 973
# Processing sample 974
# Processing sample 975
# Processing sample 976
# Processing sample 977
# Processing sample 978
# Processing sample 979
# Processing sample 980
# Processing sample 981
# Processing sample 982
# Processing sample 983
# Processing sample 984
# Processing sample 985
# Processing sample 986
# Processing sample 987
# Processing sample 988
# Processing sample 989
# Processing sample 990
# Processing sample 991
# Processing sample 992
# Processing sample 993
# Processing sample 994
# Processing sample 995
# Processing sample 996
# Processing sample 997
# Processing sample 998
# Processing sample 999
# Processing sample 1000
# Processing sample 1001
# Processing sample 1002
# Processing sample 1003
# Processing sample 1004
# Processing sample 1005
# Processing sample 1006
# Processing sample 1007
# Processing sample 1008
# Processing sample 1009
# Processing sample 1010
# Processing sample 1011
# Processing sample 1012
# Processing sample 1013
# Processing sample 1014
# Processing sample 1015
# Processing sample 1016
# Processing sample 1017
# Processing sample 1018
# Processing sample 1019
# Processing sample 1020
# Processing sample 1021
# Processing sample 1022
# Processing sample 1023
# Processing sample 1024
# Processing sample 1025
# Processing sample 1026
# Processing sample 1027
# Processing sample 1028
# Processing sample 1029
# Processing sample 1030
# Processing sample 1031
# Processing sample 1032
# Processing sample 1033
# Processing sample 1034
# Processing sample 1035
# Processing sample 1036
# Processing sample 1037
# Processing sample 1038
# Processing sample 1039
# Processing sample 1040
# Processing sample 1041
# Processing sample 1042
# Processing sample 1043
# Processing sample 1044
# Processing sample 1045
# Processing sample 1046
# Processing sample 1047
# Processing sample 1048
# Processing sample 1049
# Processing sample 1050
# Processing sample 1051
# Processing sample 1052
# Processing sample 1053
# Processing sample 1054
# Processing sample 1055
# Processing sample 1056
# Processing sample 1057
# Processing sample 1058
# Processing sample 1059
# Processing sample 1060
# Processing sample 1061
# Processing sample 1062
# Processing sample 1063
# Processing sample 1064
# Processing sample 1065
# Processing sample 1066
# Processing sample 1067
# Processing sample 1068
# Processing sample 1069
# Processing sample 1070
# Processing sample 1071
# Processing sample 1072
# Processing sample 1073
# Processing sample 1074
# Processing sample 1075
# Processing sample 1076
# Processing sample 1077
# Processing sample 1078
# Processing sample 1079
# Processing sample 1080
# Processing sample 1081
# Processing sample 1082
# Processing sample 1083
# Processing sample 1084
# Processing sample 1085
# Processing sample 1086
# Processing sample 1087
# Processing sample 1088
# Processing sample 1089
# Processing sample 1090
# Processing sample 1091
# Processing sample 1092
# Processing sample 1093
# Processing sample 1094
# Processing sample 1095
# Processing sample 1096
# Processing sample 1097
# Processing sample 1098
# Processing sample 1099
# Processing sample 1100
# Processing sample 1101
# Processing sample 1102
# Processing sample 1103
# Processing sample 1104
# Processing sample 1105
# Processing sample 1106
# Processing sample 1107
# Processing sample 1108
# Processing sample 1109
# Processing sample 1110
# Processing sample 1111
# Processing sample 1112
# Processing sample 1113
# Processing sample 1114
# Processing sample 1115
# Processing sample 1116
# Processing sample 1117
# Processing sample 1118
# Processing sample 1119
# Processing sample 1120
# Processing sample 1121
# Processing sample 1122
# Processing sample 1123
# Processing sample 1124
# Processing sample 1125
# Processing sample 1126
# Processing sample 1127
# Processing sample 1128
# Processing sample 1129
# Processing sample 1130
# Processing sample 1131
# Processing sample 1132
# Processing sample 1133
# Processing sample 1134
# Processing sample 1135
# Processing sample 1136
# Processing sample 1137
# Processing sample 1138
# Processing sample 1139
# Processing sample 1140
# Processing sample 1141
# Processing sample 1142
# Processing sample 1143
# Processing sample 1144
# Processing sample 1145
# Processing sample 1146
# Processing sample 1147
# Processing sample 1148
# Processing sample 1149
# Processing sample 1150
# Processing sample 1151
# Processing sample 1152
# Processing sample 1153
# Processing sample 1154
# Processing sample 1155
# Processing sample 1156
# Processing sample 1157
# Processing sample 1158
# Processing sample 1159
# Processing sample 1160
# Processing sample 1161
# Processing sample 1162
# Processing sample 1163
# Processing sample 1164
# Processing sample 1165
# Processing sample 1166
# Processing sample 1167
# Processing sample 1168
# Processing sample 1169
# Processing sample 1170
# Processing sample 1171
# Processing sample 1172
# Processing sample 1173
# Processing sample 1174
# Processing sample 1175
# Processing sample 1176
# Processing sample 1177
# Processing sample 1178
# Processing sample 1179
# Processing sample 1180
# Processing sample 1181
# Processing sample 1182
# Processing sample 1183
# Processing sample 1184
# Processing sample 1185
# Processing sample 1186
# Processing sample 1187
# Processing sample 1188
# Processing sample 1189
# Processing sample 1190
# Processing sample 1191
# Processing sample 1192
# Processing sample 1193
# Processing sample 1194
# Processing sample 1195
# Processing sample 1196
# Processing sample 1197
# Processing sample 1198
# Processing sample 1199
# Processing sample 0
# Processing sample 1
# Processing sample 2
# Processing sample 3
# Processing sample 4
# Processing sample 5
# Processing sample 6
# Processing sample 7
# Processing sample 8
# Processing sample 9
# Processing sample 10
# Processing sample 11
# Processing sample 12
# Processing sample 13
# Processing sample 14
# Processing sample 15
# Processing sample 16
# Processing sample 17
# Processing sample 18
# Processing sample 19
# Processing sample 20
# Processing sample 21
# Processing sample 22
# Processing sample 23
# Processing sample 24
# Processing sample 25
# Processing sample 26
# Processing sample 27
# Processing sample 28
# Processing sample 29
# Processing sample 30
# Processing sample 31
# Processing sample 32
# Processing sample 33
# Processing sample 34
# Processing sample 35
# Processing sample 36
# Processing sample 37
# Processing sample 38
# Processing sample 39
# Processing sample 40
# Processing sample 41
# Processing sample 42
# Processing sample 43
# Processing sample 44
# Processing sample 45
# Processing sample 46
# Processing sample 47
# Processing sample 48
# Processing sample 49
# Processing sample 50
# Processing sample 51
# Processing sample 52
# Processing sample 53
# Processing sample 54
# Processing sample 55
# Processing sample 56
# Processing sample 57
# Processing sample 58
# Processing sample 59
# Processing sample 60
# Processing sample 61
# Processing sample 62
# Processing sample 63
# Processing sample 64
# Processing sample 65
# Processing sample 66
# Processing sample 67
# Processing sample 68
# Processing sample 69
# Processing sample 70
# Processing sample 71
# Processing sample 72
# Processing sample 73
# Processing sample 74
# Processing sample 75
# Processing sample 76
# Processing sample 77
# Processing sample 78
# Processing sample 79
# Processing sample 80
# Processing sample 81
# Processing sample 82
# Processing sample 83
# Processing sample 84
# Processing sample 85
# Processing sample 86
# Processing sample 87
# Processing sample 88
# Processing sample 89
# Processing sample 90
# Processing sample 91
# Processing sample 92
# Processing sample 93
# Processing sample 94
# Processing sample 95
# Processing sample 96
# Processing sample 97
# Processing sample 98
# Processing sample 99
# Processing sample 100
# Processing sample 101
# Processing sample 102
# Processing sample 103
# Processing sample 104
# Processing sample 105
# Processing sample 106
# Processing sample 107
# Processing sample 108
# Processing sample 109
# Processing sample 110
# Processing sample 111
# Processing sample 112
# Processing sample 113
# Processing sample 114
# Processing sample 115
# Processing sample 116
# Processing sample 117
# Processing sample 118
# Processing sample 119
# Processing sample 120
# Processing sample 121
# Processing sample 122
# Processing sample 123
# Processing sample 124
# Processing sample 125
# Processing sample 126
# Processing sample 127
# Processing sample 128
# Processing sample 129
# Processing sample 130
# Processing sample 131
# Processing sample 132
# Processing sample 133
# Processing sample 134
# Processing sample 135
# Processing sample 136
# Processing sample 137
# Processing sample 138
# Processing sample 139
# Processing sample 140
# Processing sample 141
# Processing sample 142
# Processing sample 143
# Processing sample 144
# Processing sample 145
# Processing sample 146
# Processing sample 147
# Processing sample 148
# Processing sample 149
# Processing sample 150
# Processing sample 151
# Processing sample 152
# Processing sample 153
# Processing sample 154
# Processing sample 155
# Processing sample 156
# Processing sample 157
# Processing sample 158
# Processing sample 159
# Processing sample 160
# Processing sample 161
# Processing sample 162
# Processing sample 163
# Processing sample 164
# Processing sample 165
# Processing sample 166
# Processing sample 167
# Processing sample 168
# Processing sample 169
# Processing sample 170
# Processing sample 171
# Processing sample 172
# Processing sample 173
# Processing sample 174
# Processing sample 175
# Processing sample 176
# Processing sample 177
# Processing sample 178
# Processing sample 179
# Processing sample 180
# Processing sample 181
# Processing sample 182
# Processing sample 183
# Processing sample 184
# Processing sample 185
# Processing sample 186
# Processing sample 187
# Processing sample 188
# Processing sample 189
# Processing sample 190
# Processing sample 191
# Processing sample 192
# Processing sample 193
# Processing sample 194
# Processing sample 195
# Processing sample 196
# Processing sample 197
# Processing sample 198
# Processing sample 199
# Processing sample 200
# Processing sample 201
# Processing sample 202
# Processing sample 203
# Processing sample 204
# Processing sample 205
# Processing sample 206
# Processing sample 207
# Processing sample 208
# Processing sample 209
# Processing sample 210
# Processing sample 211
# Processing sample 212
# Processing sample 213
# Processing sample 214
# Processing sample 215
# Processing sample 216
# Processing sample 217
# Processing sample 218
# Processing sample 219
# Processing sample 220
# Processing sample 221
# Processing sample 222
# Processing sample 223
# Processing sample 224
# Processing sample 225
# Processing sample 226
# Processing sample 227
# Processing sample 228
# Processing sample 229
# Processing sample 230
# Processing sample 231
# Processing sample 232
# Processing sample 233
# Processing sample 234
# Processing sample 235
# Processing sample 236
# Processing sample 237
# Processing sample 238
# Processing sample 239
# Processing sample 240
# Processing sample 241
# Processing sample 242
# Processing sample 243
# Processing sample 244
# Processing sample 245
# Processing sample 246
# Processing sample 247
# Processing sample 248
# Processing sample 249
# Processing sample 250
# Processing sample 251
# Processing sample 252
# Processing sample 253
# Processing sample 254
# Processing sample 255
# Processing sample 256
# Processing sample 257
# Processing sample 258
# Processing sample 259
# Processing sample 260
# Processing sample 261
# Processing sample 262
# Processing sample 263
# Processing sample 264
# Processing sample 265
# Processing sample 266
# Processing sample 267
# Processing sample 268
# Processing sample 269
# Processing sample 270
# Processing sample 271
# Processing sample 272
# Processing sample 273
# Processing sample 274
# Processing sample 275
# Processing sample 276
# Processing sample 277
# Processing sample 278
# Processing sample 279
# Processing sample 280
# Processing sample 281
# Processing sample 282
# Processing sample 283
# Processing sample 284
# Processing sample 285
# Processing sample 286
# Processing sample 287
# Processing sample 288
# Processing sample 289
# Processing sample 290
# Processing sample 291
# Processing sample 292
# Processing sample 293
# Processing sample 294
# Processing sample 295
# Processing sample 296
# Processing sample 297
# Processing sample 298
# Processing sample 299
# Processing sample 300
# Processing sample 301
# Processing sample 302
# Processing sample 303
# Processing sample 304
# Processing sample 305
# Processing sample 306
# Processing sample 307
# Processing sample 308
# Processing sample 309
# Processing sample 310
# Processing sample 311
# Processing sample 312
# Processing sample 313
# Processing sample 314
# Processing sample 315
# Processing sample 316
# Processing sample 317
# Processing sample 318
# Processing sample 319
# Processing sample 320
# Processing sample 321
# Processing sample 322
# Processing sample 323
# Processing sample 324
# Processing sample 325
# Processing sample 326
# Processing sample 327
# Processing sample 328
# Processing sample 329
# Processing sample 330
# Processing sample 331
# Processing sample 332
# Processing sample 333
# Processing sample 334
# Processing sample 335
# Processing sample 336
# Processing sample 337
# Processing sample 338
# Processing sample 339
# Processing sample 340
# Processing sample 341
# Processing sample 342
# Processing sample 343
# Processing sample 344
# Processing sample 345
# Processing sample 346
# Processing sample 347
# Processing sample 348
# Processing sample 349
# Processing sample 350
# Processing sample 351
# Processing sample 352
# Processing sample 353
# Processing sample 354
# Processing sample 355
# Processing sample 356
# Processing sample 357
# Processing sample 358
# Processing sample 359
# Processing sample 360
# Processing sample 361
# Processing sample 362
# Processing sample 363
# Processing sample 364
# Processing sample 365
# Processing sample 366
# Processing sample 367
# Processing sample 368
# Processing sample 369
# Processing sample 370
# Processing sample 371
# Processing sample 372
# Processing sample 373
# Processing sample 374
# Processing sample 375
# Processing sample 376
# Processing sample 377
# Processing sample 378
# Processing sample 379
# Processing sample 380
# Processing sample 381
# Processing sample 382
# Processing sample 383
# Processing sample 384
# Processing sample 385
# Processing sample 386
# Processing sample 387
# Processing sample 388
# Processing sample 389
# Processing sample 390
# Processing sample 391
# Processing sample 392
# Processing sample 393
# Processing sample 394
# Processing sample 395
# Processing sample 396
# Processing sample 397
# Processing sample 398
# Processing sample 399
# Processing sample 400
# Processing sample 401
# Processing sample 402
# Processing sample 403
# Processing sample 404
# Processing sample 405
# Processing sample 406
# Processing sample 407
# Processing sample 408
# Processing sample 409
# Processing sample 410
# Processing sample 411
# Processing sample 412
# Processing sample 413
# Processing sample 414
# Processing sample 415
# Processing sample 416
# Processing sample 417
# Processing sample 418
# Processing sample 419
# Processing sample 420
# Processing sample 421
# Processing sample 422
# Processing sample 423
# Processing sample 424
# Processing sample 425
# Processing sample 426
# Processing sample 427
# Processing sample 428
# Processing sample 429
# Processing sample 430
# Processing sample 431
# Processing sample 432
# Processing sample 433
# Processing sample 434
# Processing sample 435
# Processing sample 436
# Processing sample 437
# Processing sample 438
# Processing sample 439
# Processing sample 440
# Processing sample 441
# Processing sample 442
# Processing sample 443
# Processing sample 444
# Processing sample 445
# Processing sample 446
# Processing sample 447
# Processing sample 448
# Processing sample 449
# Processing sample 450
# Processing sample 451
# Processing sample 452
# Processing sample 453
# Processing sample 454
# Processing sample 455
# Processing sample 456
# Processing sample 457
# Processing sample 458
# Processing sample 459
# Processing sample 460
# Processing sample 461
# Processing sample 462
# Processing sample 463
# Processing sample 464
# Processing sample 465
# Processing sample 466
# Processing sample 467
# Processing sample 468
# Processing sample 469
# Processing sample 470
# Processing sample 471
# Processing sample 472
# Processing sample 473
# Processing sample 474
# Processing sample 475
# Processing sample 476
# Processing sample 477
# Processing sample 478
# Processing sample 479
# Processing sample 480
# Processing sample 481
# Processing sample 482
# Processing sample 483
# Processing sample 484
# Processing sample 485
# Processing sample 486
# Processing sample 487
# Processing sample 488
# Processing sample 489
# Processing sample 490
# Processing sample 491
# Processing sample 492
# Processing sample 493
# Processing sample 494
# Processing sample 495
# Processing sample 496
# Processing sample 497
# Processing sample 498
# Processing sample 499
# Processing sample 500
# Processing sample 501
# Processing sample 502
# Processing sample 503
# Processing sample 504
# Processing sample 505
# Processing sample 506
# Processing sample 507
# Processing sample 508
# Processing sample 509
# Processing sample 510
# Processing sample 511
# Processing sample 512
# Processing sample 513
# Processing sample 514
# Processing sample 515
# Processing sample 516
# Processing sample 517
# Processing sample 518
# Processing sample 519
# Processing sample 520
# Processing sample 521
# Processing sample 522
# Processing sample 523
# Processing sample 524
# Processing sample 525
# Processing sample 526
# Processing sample 527
# Processing sample 528
# Processing sample 529
# Processing sample 530
# Processing sample 531
# Processing sample 532
# Processing sample 533
# Processing sample 534
# Processing sample 535
# Processing sample 536
# Processing sample 537
# Processing sample 538
# Processing sample 539
# Processing sample 540
# Processing sample 541
# Processing sample 542
# Processing sample 543
# Processing sample 544
# Processing sample 545
# Processing sample 546
# Processing sample 547
# Processing sample 548
# Processing sample 549
# Processing sample 550
# Processing sample 551
# Processing sample 552
# Processing sample 553
# Processing sample 554
# Processing sample 555
# Processing sample 556
# Processing sample 557
# Processing sample 558
# Processing sample 559
# Processing sample 560
# Processing sample 561
# Processing sample 562
# Processing sample 563
# Processing sample 564
# Processing sample 565
# Processing sample 566
# Processing sample 567
# Processing sample 568
# Processing sample 569
# Processing sample 570
# Processing sample 571
# Processing sample 572
# Processing sample 573
# Processing sample 574
# Processing sample 575
# Processing sample 576
# Processing sample 577
# Processing sample 578
# Processing sample 579
# Processing sample 580
# Processing sample 581
# Processing sample 582
# Processing sample 583
# Processing sample 584
# Processing sample 585
# Processing sample 586
# Processing sample 587
# Processing sample 588
# Processing sample 589
# Processing sample 590
# Processing sample 591
# Processing sample 592
# Processing sample 593
# Processing sample 594
# Processing sample 595
# Processing sample 596
# Processing sample 597
# Processing sample 598
# Processing sample 599
# Processing sample 600
# Processing sample 601
# Processing sample 602
# Processing sample 603
# Processing sample 604
# Processing sample 605
# Processing sample 606
# Processing sample 607
# Processing sample 608
# Processing sample 609
# Processing sample 610
# Processing sample 611
# Processing sample 612
# Processing sample 613
# Processing sample 614
# Processing sample 615
# Processing sample 616
# Processing sample 617
# Processing sample 618
# Processing sample 619
# Processing sample 620
# Processing sample 621
# Processing sample 622
# Processing sample 623
# Processing sample 624
# Processing sample 625
# Processing sample 626
# Processing sample 627
# Processing sample 628
# Processing sample 629
# Processing sample 630
# Processing sample 631
# Processing sample 632
# Processing sample 633
# Processing sample 634
# Processing sample 635
# Processing sample 636
# Processing sample 637
# Processing sample 638
# Processing sample 639
# Processing sample 640
# Processing sample 641
# Processing sample 642
# Processing sample 643
# Processing sample 644
# Processing sample 645
# Processing sample 646
# Processing sample 647
# Processing sample 648
# Processing sample 649
# Processing sample 650
# Processing sample 651
# Processing sample 652
# Processing sample 653
# Processing sample 654
# Processing sample 655
# Processing sample 656
# Processing sample 657
# Processing sample 658
# Processing sample 659
# Processing sample 660
# Processing sample 661
# Processing sample 662
# Processing sample 663
# Processing sample 664
# Processing sample 665
# Processing sample 666
# Processing sample 667
# Processing sample 668
# Processing sample 669
# Processing sample 670
# Processing sample 671
# Processing sample 672
# Processing sample 673
# Processing sample 674
# Processing sample 675
# Processing sample 676
# Processing sample 677
# Processing sample 678
# Processing sample 679
# Processing sample 680
# Processing sample 681
# Processing sample 682
# Processing sample 683
# Processing sample 684
# Processing sample 685
# Processing sample 686
# Processing sample 687
# Processing sample 688
# Processing sample 689
# Processing sample 690
# Processing sample 691
# Processing sample 692
# Processing sample 693
# Processing sample 694
# Processing sample 695
# Processing sample 696
# Processing sample 697
# Processing sample 698
# Processing sample 699
# Processing sample 700
# Processing sample 701
# Processing sample 702
# Processing sample 703
# Processing sample 704
# Processing sample 705
# Processing sample 706
# Processing sample 707
# Processing sample 708
# Processing sample 709
# Processing sample 710
# Processing sample 711
# Processing sample 712
# Processing sample 713
# Processing sample 714
# Processing sample 715
# Processing sample 716
# Processing sample 717
# Processing sample 718
# Processing sample 719
# Processing sample 720
# Processing sample 721
# Processing sample 722
# Processing sample 723
# Processing sample 724
# Processing sample 725
# Processing sample 726
# Processing sample 727
# Processing sample 728
# Processing sample 729
# Processing sample 730
# Processing sample 731
# Processing sample 732
# Processing sample 733
# Processing sample 734
# Processing sample 735
# Processing sample 736
# Processing sample 737
# Processing sample 738
# Processing sample 739
# Processing sample 740
# Processing sample 741
# Processing sample 742
# Processing sample 743
# Processing sample 744
# Processing sample 745
# Processing sample 746
# Processing sample 747
# Processing sample 748
# Processing sample 749
# Processing sample 750
# Processing sample 751
# Processing sample 752
# Processing sample 753
# Processing sample 754
# Processing sample 755
# Processing sample 756
# Processing sample 757
# Processing sample 758
# Processing sample 759
# Processing sample 760
# Processing sample 761
# Processing sample 762
# Processing sample 763
# Processing sample 764
# Processing sample 765
# Processing sample 766
# Processing sample 767
# Processing sample 768
# Processing sample 769
# Processing sample 770
# Processing sample 771
# Processing sample 772
# Processing sample 773
# Processing sample 774
# Processing sample 775
# Processing sample 776
# Processing sample 777
# Processing sample 778
# Processing sample 779
# Processing sample 780
# Processing sample 781
# Processing sample 782
# Processing sample 783
# Processing sample 784
# Processing sample 785
# Processing sample 786
# Processing sample 787
# Processing sample 788
# Processing sample 789
# Processing sample 790
# Processing sample 791
# Processing sample 792
# Processing sample 793
# Processing sample 794
# Processing sample 795
# Processing sample 796
# Processing sample 797
# Processing sample 798
# Processing sample 799
